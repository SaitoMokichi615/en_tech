# %%
#OpenCVサンプル
# %matplotlib inline
import cv2
from google.colab import files
import numpy as np
import matplotlib.pyplot as plt

#画像ファイルを選択し読み込む
uploaded_file = files.upload()

#ファイル名を取得する
uploaded_file_name = next(iter(uploaded_file))
print(uploaded_file_name)
# Out:
#      <input type="file" id="files-bb9ca599-443b-4c6f-9224-676a338d16f2" name="files[]" multiple disabled />
#      <output id="result-bb9ca599-443b-4c6f-9224-676a338d16f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prf.png to prf (4).png
# prf.png

# %%
#OpenCVで画像データを読み込む
src = cv2.imread(uploaded_file_name)

#RGBへ変換
img = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)

#画像を表示する
plt.imshow(img)

# %%
#画像データをグレースケール化
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY);

#ラプラシアンフィルタでエッジ検出
edge = cv2.Laplacian(gray_img, cv2.CV_32F)

#グレースケール画像を表示する
plt.imshow(edge)
plt.gray()
plt.show()
